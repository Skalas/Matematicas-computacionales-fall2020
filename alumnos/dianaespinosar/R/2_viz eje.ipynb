# %%
library(ggplot2)
library(scales)
install.packages('ggthemes', dependencies = TRUE)
install.packages("plotly")
library(ggthemes)
##install.packages('meta', dependencies = TRUE)
library(gridExtra)
##install.packages('gridExtra', dependencies = TRUE)
library(lubridate)
##install.packages('VGAMdata', dependencies = TRUE)
library(ggplot2movies)
##install.packages('ggplot2movies', dependencies = TRUE)
##install.packages('MASS', dependencies = TRUE)
##install.packages('UsingR', dependencies = TRUE)
#install.packages('DAAG', dependencies = TRUE)
# Out:
# also installing the dependencies ‘systemfonts’, ‘gdtools’, ‘vdiffr’
#
#
# Warning message in install.packages("ggthemes", dependencies = TRUE):
# “installation of package ‘systemfonts’ had non-zero exit status”
# Warning message in install.packages("ggthemes", dependencies = TRUE):
# “installation of package ‘gdtools’ had non-zero exit status”
# Warning message in install.packages("ggthemes", dependencies = TRUE):
# “installation of package ‘vdiffr’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
data(Fleiss93, package="meta")
Fleiss93 <- within(Fleiss93, {
                   total <- n.e + n.c
                   st <- reorder(study, -(total)) })
ggplot(Fleiss93, aes(st, total)) + geom_bar(stat="identity") +
       xlab("") + ylab("") + ylim(0,20000)
# Out:
# plot without title

# %%
Fleiss93
# Out:
#   study  year event.e n.e  event.c n.c  st     total
# 1 MRC-1  1974   49     615   67     624 MRC-1   1239
# 2 CDP    1976   44     758   64     771 CDP     1529
# 3 MRC-2  1979  102     832  126     850 MRC-2   1682
# 4 GASP   1979   32     317   38     309 GASP     626
# 5 PARIS  1980   85     810   52     406 PARIS   1216
# 6 AMIS   1980  246    2267  219    2257 AMIS    4524
# 7 ISIS-2 1988 1570    8587 1720    8600 ISIS-2 17187

# %% [markdown]
# # Titanic

# %%
data.frame(Titanic)
# Out:
#    Class Sex    Age   Survived Freq
# 1  1st   Male   Child No         0
# 2  2nd   Male   Child No         0
# 3  3rd   Male   Child No        35
# 4  Crew  Male   Child No         0
# 5  1st   Female Child No         0
# 6  2nd   Female Child No         0
# 7  3rd   Female Child No        17
# 8  Crew  Female Child No         0
# 9  1st   Male   Adult No       118
# 10 2nd   Male   Adult No       154
# 11 3rd   Male   Adult No       387
# 12 Crew  Male   Adult No       670
# 13 1st   Female Adult No         4
# 14 2nd   Female Adult No        13
# 15 3rd   Female Adult No        89
# 16 Crew  Female Adult No         3
# 17 1st   Male   Child Yes        5
# 18 2nd   Male   Child Yes       11
# 19 3rd   Male   Child Yes       13
# 20 Crew  Male   Child Yes        0
# 21 1st   Female Child Yes        1
# 22 2nd   Female Child Yes       13
# 23 3rd   Female Child Yes       14
# 24 Crew  Female Child Yes        0
# 25 1st   Male   Adult Yes       57
# 26 2nd   Male   Adult Yes       14
# ...

# %%
library(gridExtra)
Titanic1 <- data.frame(Titanic)
p <- ggplot(Titanic1, aes(weight=Freq)) +
            ylab("") + ylim(0,2250)
cs <- p + aes(Class) + geom_bar(fill="blue")
sx <- p + aes(Sex) + geom_bar(fill="green")
ag <- p + aes(Age) + geom_bar(fill="tan2")
su <- p + aes(Survived) + geom_bar(fill="red")
grid.arrange(cs, sx, ag, su, nrow=1, widths=c(3, 2, 2, 2))
# Out:
# plot without title

# %%
if(!require(dplyr, quietly = TRUE, warn.conflicts = FALSE) ){
    install.packages('dplyr',
	    dependencies = TRUE, 
	    repos = "http://cran.us.r-project.org")
}

# %%
data.frame(Titanic) %>% 
group_by(Class) %>%
summarise (count = sum(Freq))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Class count
# 1 1st   325
# 2 2nd   285
# 3 3rd   706
# 4 Crew  885

# %% [markdown]
# # Olympics

# %%
data(oly12, package="VGAMdata")

# %% [markdown]
# # Movies

# %%
ggplot(movies, aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# plot without title

# %%
head(movies)
# Out:
#   title                    year length budget rating votes r1   r2   r3  r4   ⋯
# 1 $                        1971 121    NA     6.4    348    4.5  4.5 4.5  4.5 ⋯
# 2 $1000 a Touchdown        1939  71    NA     6.0     20    0.0 14.5 4.5 24.5 ⋯
# 3 $21 a Day Once a Month   1941   7    NA     8.2      5    0.0  0.0 0.0  0.0 ⋯
# 4 $40,000                  1996  70    NA     8.2      6   14.5  0.0 0.0  0.0 ⋯
# 5 $50,000 Climax Show, The 1975  71    NA     3.4     17   24.5  4.5 0.0 14.5 ⋯
# 6 $pent                    2000  91    NA     4.3     45    4.5  4.5 4.5 14.5 ⋯
#   r9   r10  mpaa Action Animation Comedy Drama Documentary Romance Short
# 1  4.5  4.5      0      0         1      1     0           0       0
# 2  4.5 14.5      0      0         1      0     0           0       0
# 3 24.5 24.5      0      1         0      0     0           0       1
# 4 34.5 45.5      0      0         1      0     0           0       0
# ...

# %%
movies1 <- movies %>% filter (votes <= 1000) #scatterplpot si quitamos los que tienen más de 1000 votos
ggplot(movies1, aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# plot without title

# %%
movies %>% filter (votes <= 1000)  %>% #OTRA FORMA DE HACERLO scatterplpot si quitamos los que tienen más de 1000 votos
ggplot( aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# plot without title

# %%
movies %>% filter (votes < 1000, votes > 9)  %>% #scatterplpot si quitamos los que tienen más de 1000 votos
ggplot( aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# plot without title

# %%
movies %>% filter (votes < 1000, votes > 9)  %>% group_by (Action, Animation, Comedy, Drama) %>% #scatterplpot si quitamos los que tienen más de 1000 votos
ggplot( aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# plot without title

# %%
movies %>% pivot_longer(cols = c(Action, Animation, Comedy, Drama, Documentary, Romance, Short), names_to = "category", values_to = "figure") %>%
data.frame() %>% head()
# Out:
#   title year length budget rating votes r1  r2  r3  r4  r5   r6   r7   r8   r9
# 1 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
# 2 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
# 3 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
# 4 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
# 5 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
# 6 $     1971 121    NA     6.4    348   4.5 4.5 4.5 4.5 14.5 24.5 24.5 14.5 4.5
#   r10 mpaa category    figure
# 1 4.5      Action      0
# 2 4.5      Animation   0
# 3 4.5      Comedy      1
# 4 4.5      Drama       1
# 5 4.5      Documentary 0
# 6 4.5      Romance     0

# %%
install.packages("dslabs")

# %% [markdown]
# # Autos:

# %%
data(Cars93, package="MASS")
ggplot(Cars93, aes(Weight, MPG.city)) + geom_point() +
       geom_smooth(colour="green") + ylim(0,50)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
head(Cars93)
# Out:
#   Manufacturer Model   Type    Min.Price Price Max.Price MPG.city MPG.highway
# 1 Acura        Integra Small   12.9      15.9  18.8      25       31
# 2 Acura        Legend  Midsize 29.2      33.9  38.7      18       25
# 3 Audi         90      Compact 25.9      29.1  32.3      20       26
# 4 Audi         100     Midsize 30.8      37.7  44.6      19       26
# 5 BMW          535i    Midsize 23.7      30.0  36.2      22       30
# 6 Buick        Century Midsize 14.2      15.7  17.3      22       31
#   AirBags            DriveTrain ⋯ Passengers Length Wheelbase Width Turn.circle
# 1 None               Front      ⋯ 5          177    102       68    37
# 2 Driver & Passenger Front      ⋯ 5          195    115       71    38
# 3 Driver only        Front      ⋯ 5          180    102       67    37
# 4 Driver & Passenger Front      ⋯ 6          193    106       70    37
# 5 Driver only        Rear       ⋯ 4          186    109       69    39
# ...

# %%
#Grafiquen 1/MPG.City, vs horsepowerhay ¿una relación lineal? ¿Cuáles son los outliers?

# %%
Cars93 %>% mutate(inverse = 1/MPG.city) %>%
ggplot(aes(x = Horsepower, y = inverse)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# # Máquinas tragamonedas

# %%
data(vlt, package = "DAAG")
vlt
# Out:
#     window1 window2 window3 prize night
# 1   2       0       0       0     1
# 2   0       5       1       0     1
# 3   0       0       0       0     1
# 4   2       0       0       0     1
# 5   0       0       0       0     1
# 6   0       0       1       0     1
# 7   1       0       1       0     1
# 8   0       0       0       0     1
# 9   1       2       1       5     1
# 10  0       0       1       0     1
# 11  7       2       2       0     1
# 12  0       7       0       0     1
# 13  1       0       6       2     1
# 14  1       2       1       5     1
# 15  1       0       7       0     1
# 16  0       2       0       0     1
# 17  0       0       0       0     1
# 18  1       0       0       0     1
# 19  2       0       0       0     1
# 20  1       0       6       2     1
# 21  0       7       1       0     1
# 22  0       0       1       0     1
# 23  1       2       0       0     1
# 24  1       0       0       0     1
# 25  0       0       0       0     1
# ...

# %%
vlt %>% group_by(window1) %>% summarise(n = n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   window1 n
# 1 0       141
# 2 1       132
# 3 2        30
# 4 3        14
# 5 5         7
# 6 6         6
# 7 7        15

# %%
vlt %>% group_by(window2) %>% summarise(n = n())
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   window2 n
# 1 0       192
# 2 1        23
# 3 2        65
# 4 3        46
# 5 5        10
# 6 6         1
# 7 7         8

# %%
vlt %>% group_by(window3) %>% summarise(n = n()) %>% ggplot(aes(weight = n)) + aes(window3) + geom_bar(fill = 'blue')
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
# plot without title

# %%
library(tidyr)

# %%
vlt %>% pivot_longer(cols = starts_with ('window'), names_to = "window", values_to = "figure") %>%
group_by(window,figure) %>% summarise(n = n()) %>%
ggplot(aes(x = figure, weight = n, fill = window)) + facet_wrap(~window) + geom_bar()
# Out:
# `summarise()` regrouping output by 'window' (override with `.groups` argument)
# plot without title
