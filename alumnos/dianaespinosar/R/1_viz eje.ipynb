# %%
library(ggplot2)
library(scales)
#install.packages('ggthemes', dependencies = TRUE)
library(ggthemes)

# %% [markdown]
# # Velocidad de la Luz

# %%
library(MASS)
vl <- data.frame(michelson)

# %%
vl
# Out:
#     Speed Run Expt
# 1    850  1   1
# 2    740  2   1
# 3    900  3   1
# 4   1070  4   1
# 5    930  5   1
# 6    850  6   1
# 7    950  7   1
# 8    980  8   1
# 9    980  9   1
# 10   880  10  1
# 11  1000  11  1
# 12   980  12  1
# 13   930  13  1
# 14   650  14  1
# 15   760  15  1
# 16   810  16  1
# 17  1000  17  1
# 18  1000  18  1
# 19   960  19  1
# 20   960  20  1
# 21   960  1   2
# 22   940  2   2
# 23   960  3   2
# 24   940  4   2
# 25   880  5   2
# 26   800  6   2
# 27   850  7   2
# 28   880  8   2
# 29   900  9   2
# 30   840  10  2
# ⋮   ⋮     ⋮   ⋮
# 71  910   11  4
# 72  920   12  4
# 73  890   13  4
# 74  860   14  4
# 75  880   15  4
# 76  720   16  4
# 77  840   17  4
# 78  850   18  4
# 79  850   19  4
# 80  780   20  4
# 81  890   1   5
# 82  840   2   5
# 83  780   3   5
# 84  810   4   5
# 85  760   5   5
# 86  810   6   5
# 87  790   7   5
# 88  810   8   5
# 89  820   9   5
# 90  850   10  5
# 91  870   11  5
# 92  870   12  5
# 93  810   13  5
# ...

# %%
ggplot(vl, aes(Speed, Run, color= Expt)) +
       geom_point() + theme(legend.position="bottom")+
# Out:
# Error in parse(text = x, srcfile = src): <text>:4:0: unexpected end of input
# 2:        geom_point() + theme(legend.position="bottom")+
# 3:
#   ^
# Traceback:

# %%
ggplot(vl, aes(Speed, fill = Expt)) +
       geom_histogram(binwidth = 100) + xlab("Speed") + 
ylab("Run") + facet_grid(~Expt) +  theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# # Pima Indians

# %%
Pima.tr2
# Out:
#     npreg glu bp skin bmi  ped   age type
# 1    5     86 68 28   30.2 0.364 24  No
# 2    7    195 70 33   25.1 0.163 55  Yes
# 3    5     77 82 41   35.8 0.156 35  No
# 4    0    165 76 43   47.9 0.259 26  No
# 5    0    107 60 25   26.4 0.133 23  No
# 6    5     97 76 27   35.6 0.378 52  Yes
# 7    3     83 58 31   34.3 0.336 25  No
# 8    1    193 50 16   25.9 0.655 24  No
# 9    3    142 80 15   32.4 0.200 63  No
# 10   2    128 78 37   43.3 1.224 31  Yes
# 11   0    137 40 35   43.1 2.288 33  Yes
# 12   9    154 78 30   30.9 0.164 45  No
# 13   1    189 60 23   30.1 0.398 59  Yes
# 14  12     92 62  7   27.6 0.926 44  Yes
# 15   1     86 66 52   41.3 0.917 29  No
# 16   4     99 76 15   23.2 0.223 21  No
# 17   1    109 60  8   25.4 0.947 21  No
# 18  11    143 94 33   36.6 0.254 51  Yes
# 19   1    149 68 29   29.3 0.349 42  Yes
# 20   0    139 62 17   22.1 0.207 21  No
# 21   2     99 70 16   20.4 0.235 27  No
# 22   1    100 66 29   32.0 0.444 42  No
# ...

# %%
ggplot(Pima.tr2, aes(type))+geom_bar()
# Out:
# plot without title

# %%
ggplot(Pima.tr2, aes(age))+geom_bar()
# Out:
# plot without title

# %%
ggplot(Pima.tr2, aes(age,npreg))+geom_point()
# Out:
# plot without title

# %%
ggplot(Pima.tr2, aes(age, bmi, color= npreg)) +
       geom_point() + theme(legend.position="bottom")
# Out:
# Warning message:
# “Removed 3 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# # Titanic

# %%
head(data.frame(Titanic))
# Out:
#   Class Sex    Age   Survived Freq
# 1 1st   Male   Child No        0
# 2 2nd   Male   Child No        0
# 3 3rd   Male   Child No       35
# 4 Crew  Male   Child No        0
# 5 1st   Female Child No        0
# 6 2nd   Female Child No        0

# %%
if(!require(dplyr, quietly = TRUE, warn.conflicts = FALSE) ){
    install.packages('dplyr',
	    dependencies = TRUE, 
	    repos = "http://cran.us.r-project.org")
}
if(!require(nycflights13, quietly = TRUE, warn.conflicts = FALSE) ){
    install.packages('nycflights13', 
	    dependencies = TRUE, 
	    repos = "http://cran.us.r-project.org")
}

# %%
data.frame(Titanic) %>% 
group_by(Class) %>%
summarise (count = sum(Freq))
# Out:
# Error in data.frame(Titanic) %>% group_by(Class) %>% summarise(count = sum(Freq)): could not find function "%>%"
# Traceback:

# %% [markdown]
# # Galaxies
